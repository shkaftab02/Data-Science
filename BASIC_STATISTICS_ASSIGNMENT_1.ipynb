# %% [markdown]
# ## **Descriptive Analytics for Numerical Columns**

# %%
import pandas as pd
dataset = pd.read_csv('/content/sales_data_with_discounts.csv')
print(dataset.dtypes)
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
numerical_data = dataset.select_dtypes(include=['float64', 'int64'])
print(numerical_data.columns)
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
for column in numerical_data.columns:
    print(f"Statistics for {column}:")
    print(f"Mean: {numerical_data[column].mean()}")
    print(f"Median: {numerical_data[column].median()}")
    print(f"Mode: {numerical_data[column].mode()[0]}")
    print(f"Standard Deviation: {numerical_data[column].std()}")
    print()
# Out:
# Statistics for Volume:
# Mean: 5.066666666666666
# Median: 4.0
# Mode: 3
# Standard Deviation: 4.231602391213926
#
# Statistics for Avg Price:
# Mean: 10453.433333333332
# Median: 1450.0
# Mode: 400
# Standard Deviation: 18079.90483993645
#
# Statistics for Total Sales Value:
# Mean: 33812.83555555555
# Median: 5700.0
# Mode: 24300
# Standard Deviation: 50535.07417255328
#
# Statistics for Discount Rate (%):
# Mean: 15.155241895330914
# Median: 16.57776564929597
# Mode: 5.007822189204133
# Standard Deviation: 4.220602153325511
#
# Statistics for Discount Amount:
# Mean: 3346.499424342415
# Median: 988.9337332382784
# Mode: 69.17794228822787
# Standard Deviation: 4509.9029633539985
#
# Statistics for Net Sales Value:
# Mean: 30466.336131270138
# Median: 4677.788059301853
# Mode: 326.97480055470817
# Standard Deviation: 46358.656624066934

# %% [markdown]
# ## ***Data Visualization***

# %% [markdown]
# ## ●	**Histograms**

# %%
import matplotlib.pyplot as plt

numerical_data = dataset.select_dtypes(include=['float64', 'int64'])
print(numerical_data.columns)

for column in numerical_data.columns:
    plt.figure(figsize=(8, 5))
    plt.hist(numerical_data[column], bins=20, color='blue', alpha=0.7)
    plt.title(f"Histogram of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %% [markdown]
# # ●	Boxplots

# %%
import seaborn as sns

numerical_data = dataset.select_dtypes(include=['float64', 'int64'])
print(numerical_data.columns)

for column in numerical_data.columns:
    plt.figure(figsize=(8, 5))
    sns.boxplot(x=numerical_data[column], color='skyblue')
    plt.title(f"Boxplot of {column}")
    plt.xlabel(column)
    plt.grid(True)
    plt.show()
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %% [markdown]
# # **●	Bar Chart Analysis for Categorical Column**

# %%
categorical_data = dataset.select_dtypes(include=['object', 'category'])
print(categorical_data.columns)


for column in categorical_data.columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=dataset, x=column, palette='viridis')
    plt.title(f"Bar Chart of {column}")
    plt.xlabel(column)
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')
# <ipython-input-13-2c6f304debf3>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=dataset, x=column, palette='viridis')
# <ipython-input-13-2c6f304debf3>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=dataset, x=column, palette='viridis')
# <ipython-input-13-2c6f304debf3>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=dataset, x=column, palette='viridis')
# <ipython-input-13-2c6f304debf3>:7: FutureWarning:
#
# ...

# %% [markdown]
# ## **Standardization of Numerical Variables**

# %%
numerical_data = dataset.select_dtypes(include=['float64', 'int64'])
print(numerical_data.columns)

from sklearn.preprocessing import StandardScaler
import pandas as pd
scaler = StandardScaler()
standardized_data = pd.DataFrame(scaler.fit_transform(numerical_data),
                                 columns=numerical_data.columns)
data_standardized = dataset.copy()
data_standardized[numerical_data.columns] = standardized_data

print("Before Standardization:")
print(numerical_data.describe())

print("After Standardization:")
print(standardized_data.describe())
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')
# Before Standardization:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# ...

# %% [markdown]
# ## **Conversion of Categorical Data into Dummy Variables**

# %%
categorical_data = dataset.select_dtypes(include=['object', 'category'])
print(categorical_data.columns)

one_hot_encoded_data = pd.get_dummies(dataset, columns=categorical_data.columns, drop_first=False)

print(one_hot_encoded_data.head())

print("Original Dataset:")
print(dataset.head())

print("\nTransformed Dataset with One-Hot Encoding:")
print(one_hot_encoded_data.head())
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')
#    Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      15      12100             181500          11.654820     21153.498820
# 1      10      10100             101000          11.560498     11676.102961
# 2       7      16100             112700           9.456886     10657.910157
# 3       6      20100             120600           6.935385      8364.074702
# 4       3       8100              24300          17.995663      4372.946230
#
#    Net Sales Value  Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  \
# 0    160346.501180             True            False            False
# 1     89323.897039             True            False            False
# 2    102042.089843             True            False            False
# 3    112235.925298             True            False            False
# 4     19927.053770             True            False            False
#
# ...

# %% [markdown]
# ## ***Conclusion ***

# %% [markdown]
# Key Findings:
#
# Descriptive analytics (mean, median, standard deviation) showed central trends and data spread.
# Visualizations (boxplots, histograms, bar charts) helped identify outliers, distribution patterns, and category frequencies.
#
# Importance of Preprocessing:
#
# Standardization ensures features are on the same scale, improving model performance.
# One-hot encoding transforms categorical data into a format that models can use without creating false relationships.
#
# Takeaway:
#
# Preprocessing steps like standardization and one-hot encoding are essential for accurate and effective machine learning models.
